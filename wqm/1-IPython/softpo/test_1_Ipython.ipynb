# %%
# jupyter notebook
# 双击D：删除当前cell
# 单击M：转为markdown文档
# markdown文档下运行变为预览模式
# 外部文件中变量和方法，就会加载到内存中


# 1运行外部文件
# %run he.py
# %run C:\Users\softpo.DESKTOP-PN692CT\Desktop\wo.py
    
    
# 2.运行计时
'''%time一般用于耗时长的代码段
# %timeit一般用于耗时短的代码段'''
import time
# %time sum_(10000)
# 可以使用两个百分号来测试多行代码的平均运行时间
# %%timeit
sum_(100000)
sum_(1000)#6.36 ms ± 433 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)


# 3.查看当前会话中的所有变量与函数 
'''
# %who(看变量)，
# %whos看变量的详细信息
# %who_ls返回一个字符串列表，里面元素是当前会话的所有变量与函数名称：'''

# %who
#a	 b	 c	 django	 e	 random	 requests	 square	 sum_	 time	 w	
# %whos
'''
Variable   Type        Data/Info
--------------------------------
a          int         1024
b          float       0.3
c          int         1024
django     module      <module 'django' from 'C:<...>es\\django\\__init__.py'>
e          float       2.718
random     module      <module 'random' from 'C:<...>aconda3\\lib\\random.py'>
requests   module      <module 'requests' from '<...>\\requests\\__init__.py'>
square     function    <function square at 0x00000136D1435A60>
sum_       function    <function sum_ at 0x00000136D1A77158>
time       module      <module 'time' (built-in)>
w          int         55
'''



# 4.执行linux命令
# 在Linux指令之前加上 !，即可在ipython当中执行Linux指令。会将标准输出以字符串形式返回


# 5.魔法命令
lsmagic

'''Available line magics:
# %alias  %alias_magic  %autocall  %automagic  %autosave  %bookmark  %cd  %clear
# %cls  %colors  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  
# %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts 
# %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  
# %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook 
# %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %popd  %pprint  
# %precision  %profile  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  
# %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset
# %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb 
# %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode

Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%cmd  %%debug  %%file  %%html 
# %%javascript  %%js  %%latex  %%markdown  %%perl  %%prun  %%pypy  %%python 
# %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time
# %%timeit  %%writefile

Automagic is ON, % prefix IS NOT needed for line magics.'''



# 6.快捷键
6.1.命令模式 
'''• Enter : 转入编辑模式 
• Shift-Enter : 运行本单元，选中下个单元
• Ctrl-Enter : 运行本单元，选中本单元
• Alt-Enter : 运行本单元，在下面插入一单元

• Y : 单元转入代码状态
• M :单元转入markdown状态

• A : 在上方插入新单元
• B : 在下方插入新单元'''

6.2.编辑模式
'''
• Tab : 代码补全或缩进
• Shift-Tab : 提示
• Ctrl-A : 全选
• Ctrl-Z : 复原'''
